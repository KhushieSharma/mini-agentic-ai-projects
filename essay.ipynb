# %%
# from langgraph.graph import StateGraph, START,END
# from langchain_groq import ChatGroq
# from typing import TypedDict, Annotated
# from dotenv import load_dotenv
# from pydantic import BaseModel,Field
# import os
# import operator

# %%
# class essay(TypedDict):
#     essay_title:str
#     language_feedback:str
#     clarity_feedback:str
#     analysis_feedback:str
#     overall_feedback:str
# #     individual_score:Annotated[list[int],operator.add]
#     avg_score:float

# %%
# l=ChatGroq(model='gpt-4o',temperature=0.7)

# %%
# def lange(state:essay):
#     prompt=f'Evaluate the language quality of the essay and provide feedback and assign a score out of 10.\n{state['essay']}'
#     output=l.invoke(prompt)
#     return {'language_feedback': output.feedback,'individual_score':[output.score]}

# %%
# graph=StateGraph(essay)
# graph.add_node('lange',lange)
# graph.add_node('tho',tho)
# graph.add_node('anal',anal)
# graph.add_node('overall',overall)

# graph.add_edge(START,'lange')
# graph.add_edge(START,'tho')
# graph.add_edge(START,'anal')
# graph.add_edge(START,'overall')
